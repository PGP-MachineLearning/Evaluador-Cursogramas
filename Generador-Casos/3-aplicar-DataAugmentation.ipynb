# %% [markdown]
# # Programa auxiliar para generar transformaciones al azar en los casos de cursogramas (imágenes con su correspondiente XML) aplicando técnicas de "Data Augmentation"
# Basado y adaptado del código de https://medium.com/@bhuwanbhattarai/image-data-augmentation-and-parsing-into-an-xml-file-in-pascal-voc-format-for-object-detection-4cca3d24b33b

# %% [markdown]
# 0) Configurar los parámetros para la ejecución:

# %%
#@title Configurar Parámetros

#@markdown Generales:
procesar_todos_archivos_disponibles = True  #@param {type:"boolean"}
cantidad_archivos_procesar = 1500 #@param {type:"integer"}
# prefijo de archivos generados
prefijo_archivo_da = 'da' # parámetro con valor fijo

#@markdown Probabilidades de Métodos de Data Augmentation:
probab_DA_Zoom_Cambio_Tamanio = 100#@param {type:"integer"}
DA_Zoom_Cambio_Tamanio_Porcentaje_Minimo = 10 #@param {type:"slider", min:5, max:200, step:5}
DA_Zoom_Cambio_Tamanio_Porcentaje_Maximo = 100 #@param {type:"slider", min:5, max:200, step:5}
probab_DA_Estirar_Horizontal = 50 #@param {type:"integer"}
probab_DA_Estirar_Vertical = 50 #@param {type:"integer"}
probab_DA_PCA_Color = 0 #@param {type:"integer"}
probab_DA_Ruido_Gaussiano = 30 #@param {type:"integer"}
probab_DA_Ruido_Salt_and_Pepper = 50 #@param {type:"integer"}
# nota: los siguientes no tienen sentido para Cursogramas
# pero se dejan para que quede completo
probab_DA_Volteo_Vertical = 0 #-no usado- @param {type:"integer"}
probab_DA_Volteo_Horizontal = 0 #-no usado- @param {type:"integer"}
probab_DA_Rotacion = 0 #-no usado- @param {type:"integer"}

# define variables a usar luego en base a parámetros
listaMetodosDA = ['z', 'pca', 'ng', 'nsp', 'fv', 'fh', 'r', 'eh', 'ev']
listaProbabDA = [probab_DA_Zoom_Cambio_Tamanio, probab_DA_PCA_Color, probab_DA_Ruido_Gaussiano, probab_DA_Ruido_Salt_and_Pepper, probab_DA_Volteo_Vertical, probab_DA_Volteo_Horizontal, probab_DA_Rotacion, probab_DA_Estirar_Horizontal, probab_DA_Estirar_Vertical ]
if probab_DA_Zoom_Cambio_Tamanio > 0:
  if DA_Zoom_Cambio_Tamanio_Porcentaje_Minimo > DA_Zoom_Cambio_Tamanio_Porcentaje_Maximo:
    DA_Zoom_Cambio_Tamanio_Porcentaje_Maximo = DA_Zoom_Cambio_Tamanio_Porcentaje_Minimo 

#@markdown Parámetros del Drive:

# directorios locales donde se guardan las imágenes a procesar y los XMLs (pueden ser el mismo o distinto)
img_path = '/content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados' #@param {type:"string"}
xml_path = '/content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados' #@param {type:"string"}

forzar_drive_actualizar = True  #@param {type:"boolean"}

print ("Parámetros definidos.")
# Out:
# Parámetros definidos.

# %% [markdown]
# 1) Cargar librerías:

# %%
#@title Cargar Librerías
import os
import cv2
import xml.etree.cElementTree as ET
from PIL import Image
import numpy as np
import shutil

import random
from random import choices, randint, randrange

print ("Librerías cargadas.")
# Out:
# Librerías cargadas.

# %% [markdown]
# 2) Montar el Drive:

# %%
#@title Montar Google Drive
# Nota: la primera vez se debe confirmar el uso logueandose en "Google Drive File Stream" y obteniendo código de autentificación.
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 3) Realizar Data Augmentation:

# %%
#@title Definir funciones auxiliares para Data Augmentation

# función auxiliar para aplicar zoom (cambio de tamaño) en la imagen
def da_zoom(img, porc=0):
  if (porc<=0 or porc==100):
    return img
  else:
    return da_cambiarTamanio(img, porc, porc)


# función auxiliar para cambiar tamaño de la imagen 
# usando diferentes % para alto y ancho
def da_cambiarTamanio(img, porcAncho=0, porcAlto=0):
  if (porcAncho<=0 or porcAlto<=0):
    return img
  # calcula nuevo tamaño
  alto, ancho, ch = img.shape
  alto = int(float(alto * porcAlto) / 100.0)
  ancho = int(float(ancho * porcAncho) / 100.0)
  # aplica la transformación
  imgPIL = Image.fromarray((img).astype(np.uint8))
  img_out = imgPIL.resize((ancho,alto), Image.ANTIALIAS)
  img_out = np.array(img_out).astype('float32') #/ 255.0
  return img_out


# función auxiliar para aplicar PCA color augmentation
def da_pca_color(image):
    # aplica la tansformación
    assert image.ndim == 3 and image.shape[2] == 3
    assert image.dtype == np.uint8
    img = image.reshape(-1, 3).astype(np.float32)
    sf = np.sqrt(3.0/np.sum(np.var(img, axis=0)))
    img = (img - np.mean(img, axis=0))*sf 
    cov = np.cov(img, rowvar=False) # calculate the covariance matrix
    value, p = np.linalg.eig(cov) # calculation of eigen vector and eigen value 
    rand = np.random.randn(3)*0.08
    delta = np.dot(p, rand*value)
    delta = (delta*255.0).astype(np.int32)[np.newaxis, np.newaxis, :]
    img_out = np.clip(image+delta, 0, 255).astype(np.uint8)
    return img_out


# función auxiliar para aplicar ruido Gaussiano
def da_noiseG(image):
    # aplica la transformación
    row,col,ch= image.shape
    mean = 0
    var = 0.2
    sigma = var**0.5
    gauss = np.random.normal(mean,sigma,(row,col,ch))
    gauss = gauss.reshape(row,col,ch)
    noisy = image + gauss
    return noisy    


# función auxiliar para aplicar ruido Salt & Pepper
def da_noiseSP(image):
    # aplica la transformación
    prob = 0.05
    output = np.zeros(image.shape,np.uint8)
    thres = 1 - prob 
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            rdn = random.random()
            if rdn < prob:
                output[i][j] = 0
            elif rdn > thres:
                output[i][j] = 255
            else:
                output[i][j] = image[i][j]
    return output    


# función auxiliar para voltear la imagen en forma vertical
def da_flip_vertical(image):
    # aplica la transformación
    f_img = cv2.flip(image, 0)
    return f_img


# función auxiliar para voltear la imagen en forma horizontal
def da_flip_horizontal(image):
    # aplica la transformación
    f_img = cv2.flip(image, 1)
    return f_img


# función auxiliar para rotar la imagen 90 grados
def da_rotate_90(image):
    # aplica la transformación
    img_transpose = np.transpose(image, (1,0,2))
    f_img = cv2.flip(img_transpose, 1)
    return f_img


# función auxiliar para rotar la imagen 180 grados
def da_rotate_180(image):
    # aplica la transformación
    f_img = cv2.flip(image, -1)
    return f_img


# función auxiliar para rotar la imagen 270 grados
def da_rotate_270(image):
    # aplica la transformación
    img_transpose_270 = np.transpose(image, (1,0,2))
    f_img = cv2.flip(img_transpose_270, 0)
    return f_img

print ("Funciones de Data Augmentation para imágenes definidas.")
# Out:
# Funciones de Data Augmentation para imágenes definidas.

# %%
#@title Procesar archivos XMLs de cada imagen y generar transformaciones 

# levanta los xml a procesar
all_xml_array = [os.path.join(xml_path, fn) for fn in os.listdir(xml_path) if fn.endswith('.xml') and not fn.startswith(prefijo_archivo_da) ]
if not procesar_todos_archivos_disponibles:
  if len(all_xml_array) > cantidad_archivos_procesar:
    # toma una muestra al azar de acuerdo a la cantidad indicada
    all_xml_array = choices(all_xml_array,  k=cantidad_archivos_procesar )

# procesa los archivos XML
new_xml_info = []
cantXMLProc = 0
cantImgGen = 0
cantXMLGen = 0
print("\n*** Comienza procesamiento de XMLs para generar nuevas imágenes ***\n")
print("  > Cantidad de XMLs a procesar: ", len(all_xml_array), "\n")
for xml_file in all_xml_array:

    cantXMLProc = cantXMLProc + 1
    print(cantXMLProc, "- ", xml_file, ":" )

    # carga la info del XML original
    et = ET.parse(xml_file)
    element = et.getroot()
    element_objs = element.findall('object') 
    element_filename = element.find('filename').text
    img_filename = os.path.join(img_path, element_filename)
    img_split = element_filename.strip().split('.png')

    # carga la imagen
    img = cv2.imread(img_filename)
    if img is None:
      print("\t\t\t\t Error al abrir la imagen ", img_filename)
      break
    alto, ancho, ch = img.shape

    # selecciona al azar los métodos de DA que va a considerar (hasta 2)
    if procesar_todos_archivos_disponibles:
      # permita que no se aplique o hasta 3 por XML (al azar) 
      DAaplicarCant = randint(0, 3)
    else:
      # siempre aplica hasta 2 por XML (al azar)
      DAaplicarCant = randint(1, 2)
    DAaplicarMetodos = choices(listaMetodosDA, weights=listaProbabDA, k=DAaplicarCant)
    print("\t\t\t DA a aplicar: ", DAaplicarMetodos)

    # aplica los métodos correspondientes
    for mDA in DAaplicarMetodos:

      if mDA=='z':        
          # aplica cambio de tamaño en la imagen (zoom)
          DAzoomUsar = randrange(DA_Zoom_Cambio_Tamanio_Porcentaje_Minimo, DA_Zoom_Cambio_Tamanio_Porcentaje_Maximo, 5) 
          print("\t\t\t % zoom: ", DAzoomUsar)
          nuevaImg = da_zoom(img, DAzoomUsar)
          nuevaImgFN = prefijo_archivo_da + '_' + img_split[0] + '-'+ mDA + str(DAzoomUsar) + '.png'

      elif mDA=='eh' or mDA=='ev':        
          # aplica estiramiento horizontal o vertical
          porcUsar = randrange(45, 95, 5) 
          print("\t\t\t % estiramiento ", mDA[1], ": ", porcUsar)
          if mDA=='eh':
            nuevaImg = da_cambiarTamanio(img, porcAncho=porcUsar, porcAlto=100)
          else:
            nuevaImg = da_cambiarTamanio(img, porcAncho=100, porcAlto=porcUsar)
          nuevaImgFN = prefijo_archivo_da + '_' + img_split[0] + '-'+ mDA + str(porcUsar) + '.png'

      elif mDA=='pca':        
          # aplica la transformación PCA color
          nuevaImg = da_pca_color(img)
          nuevaImgFN = prefijo_archivo_da + '_' + img_split[0] + '-'+ mDA + '.png'

      elif mDA=='ng': 
          # aplica la transformación ruido Gaussiano
          nuevaImg = da_noiseG(img)        
          nuevaImgFN = prefijo_archivo_da + '_' + img_split[0] + '-'+ mDA + '.png'     

      elif mDA=='nsp':
          # aplica la transformación ruido Salt & Pepper
          nuevaImg = da_noiseSP(img)
          nuevaImgFN = prefijo_archivo_da + '_' + img_split[0] + '-'+ mDA + '.png'

      elif mDA=='fv':
          # aplica transformación de volteo vertical
          nuevaImg = da_flip_vertical(img)
          nuevaImgFN = prefijo_archivo_da + '_' + img_split[0] + '-'+ mDA + '.png'

      elif mDA=='fh':
          # aplica transformación de volteo horizontal 
          nuevaImg = da_flip_horizontal(img)
          nuevaImgFN = prefijo_archivo_da + '_' + img_split[0] + '-'+ mDA + '.png'

      elif mDA=='r':
          # aplica rotación por lo que determina al azar la cantidad de grados 
          gradosRotacion = randrange(90, 270, 90) 
          if gradosRotacion == 90:
            # aplica rotación de 90 grados 
            mDA = 'r90'
            nuevaImg = da_rotate_90(img)
            nuevaImgFN = prefijo_archivo_da + '_' + img_split[0] + '-'+ mDA + '90.png'        
          elif  gradosRotacion == 180:
            # aplica rotación de 180 grados 
            mDA = 'r180'
            nuevaImg = da_rotate_180(img)
            nuevaImgFN = prefijo_archivo_da + '_' + img_split[0] + '-'+ mDA + '180.png'           
          else:
            # aplica rotación de 270 grados 
            mDA = 'r270'
            nuevaImg = da_rotate_270(img)
            nuevaImgFN = prefijo_archivo_da + '_' + img_split[0] + '-'+ mDA + '270.png'      
      else:
        # no hace nada
        print("\t\t\t\t ¡¡Tipo DA ", mDA, " no existente!!")
        break

      # si el archivo no existe
      if os.path.isfile(os.path.join(img_path, nuevaImgFN)):
        print("\t\t\t\t ", nuevaImgFN, " ya existe, se descata transformación!!")
      else:
          # graba la nueva imagen       
          cv2.imwrite(os.path.join(img_path, nuevaImgFN), nuevaImg)
          cantImgGen = cantImgGen + 1
      
          # genera el XML de la nueva imagen   
          nuevo_xml_annotation = ET.Element('annotation')
          ET.SubElement(nuevo_xml_annotation, 'folder').text = img_path
          ET.SubElement(nuevo_xml_annotation, 'filename').text = nuevaImgFN
          ET.SubElement(nuevo_xml_annotation, 'path').text = img_path + nuevaImgFN

          nuevo_xml_source = ET.SubElement(nuevo_xml_annotation, 'source')
          ET.SubElement(nuevo_xml_source, 'database').text = 'Unknown'

          nuevo_xml_size = ET.SubElement(nuevo_xml_annotation, 'size')
          ET.SubElement(nuevo_xml_size, 'width').text = str(nuevaImg.shape[1])
          ET.SubElement(nuevo_xml_size, 'height').text = str(nuevaImg.shape[0])
          ET.SubElement(nuevo_xml_size, 'depth').text = str(nuevaImg.shape[2])

          ET.SubElement(nuevo_xml_annotation, 'segmented').text = '0'

          # procesa los elementos en el archivo XML original para generar el nuevo
          for element_obj in element_objs:

              # obtiene la información actual de la imagen
              class_name = element_obj.find('name').text 

              # obtiene info del box actual
              obj_bbox = element_obj.find('bndbox')
              x1 = int(round(float(obj_bbox.find('xmin').text)))
              y1 = int(round(float(obj_bbox.find('ymin').text)))
              x2 = int(round(float(obj_bbox.find('xmax').text)))
              y2 = int(round(float(obj_bbox.find('ymax').text)))
              
              # cambia las coordenadas del box de acuerdo al tipo de transformación aplicada
              if mDA=='pca' or mDA=='ng' or mDA=='nsp':        
                  # para la transformación PCA color, ruido Gaussiano y ruido Salt & Pepper  
                  # quedan iguales
                  f_x1 = x1
                  f_x2 = x2
                  f_y1 = y1
                  f_y2 = y2

              elif mDA=='fv':
                  # para transformación de volteo vertical, cambia
                  f_x1 = x1
                  f_y1 = alto - y2
                  f_x2 = x2
                  f_y2 = alto - y1

              elif mDA=='fh':
                  # para transformación de volteo horizontal, cambia
                  f_x1 = ancho - x2
                  f_y1 = y1
                  f_x2 = ancho - x1
                  f_y2 = y2

              elif mDA=='r90':
                  # para rotación de 90 grados, cambia
                  f_x1 = alto - y2
                  f_y1 = x1
                  f_x2 = alto - y1
                  f_y2 = x2
                
              elif mDA=='r180':
                  # para rotación de 180 grados, cambia
                  f_x1 = ancho - x2
                  f_y1 = alto - y2
                  f_x2 = ancho - x1
                  f_y2 = alto - y1   
                
              elif mDA=='r270':
                  # para rotación de 270 grados, cambia
                  f_x1 = y1
                  f_y1 = ancho - x2
                  f_x2 = y2
                  f_y2 = ancho - x1
          
              else: # elif mDA=='z' or mDA=='ev' or mDA=='eh':
                  # para zoom o estiramiento vertical/horizontal,
                  #  cambia de acuerdo a nuevo tamaño
                  f_x1 = int(x1 / ancho * nuevaImg.shape[1])
                  f_x2 = int(x2 / ancho * nuevaImg.shape[1])
                  f_y1 = int(y1 / alto * nuevaImg.shape[0])
                  f_y2 = int(y2 / alto * nuevaImg.shape[0])

              # define el nuevo box
              nuevo_xml_object = ET.SubElement(nuevo_xml_annotation, 'object')
              ET.SubElement(nuevo_xml_object, 'name').text = class_name
              ET.SubElement(nuevo_xml_object, 'pose').text = 'Unspecified'
              ET.SubElement(nuevo_xml_object, 'truncated').text = '0'
              ET.SubElement(nuevo_xml_object, 'difficult').text = '0'

              nuevo_xml_bndbox = ET.SubElement(nuevo_xml_object, 'bndbox')
              ET.SubElement(nuevo_xml_bndbox, 'xmin').text = str(f_x1)
              ET.SubElement(nuevo_xml_bndbox, 'ymin').text = str(f_y1)
              ET.SubElement(nuevo_xml_bndbox, 'xmax').text = str(f_x2)
              ET.SubElement(nuevo_xml_bndbox, 'ymax').text = str(f_y2)

          # graba el nuevo XML
          nuevoXMLfn = nuevaImgFN.replace(".png", ".xml")
          xml_tree = ET.ElementTree(nuevo_xml_annotation)
          xml_tree.write( os.path.join(xml_path, nuevoXMLfn) )
          cantXMLGen = cantXMLGen + 1

print("\n*** Fin procesamiento de de XMLs para generar nuevas imágenes ***\n\n")
print("> Imágenes/XMLs procesados: ", cantXMLProc)
print("> Imágenes nuevas generadas: ", cantImgGen)
print("> XMLs nuevas generados: ", cantXMLGen)

if forzar_drive_actualizar:
  print("\n** Forzando la actualización del drive **")
  # Fuerza la actualizacion del drive
  drive.flush_and_unmount()
  # vuelve a montar
  drive.mount('/content/gdrive', force_remount=True)
  print("**Actualización del drive terminada **")
# Out:
# *** Comienza procesamiento de XMLs para generar nuevas imágenes ***
#
#   > Cantidad de XMLs a procesar:  1495
#
# 1 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00021fr.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  30
# 2 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00022fr.xml :
# 			 DA a aplicar:  ['nsp', 'nsp', 'eh']
# 				  da_c_SFeRS_00022fr-nsp.png  ya existe, se descata transformación!!
# 			 % estiramiento  h :  60
# 3 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00023fr.xml :
# 			 DA a aplicar:  []
# 4 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00024.xml :
# 			 DA a aplicar:  ['nsp', 'z', 'z']
# 			 % zoom:  50
# 			 % zoom:  85
# 5 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00025fr.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  60
# 6 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00026fr.xml :
# 			 DA a aplicar:  []
# 7 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00027fr.xml :
# 			 DA a aplicar:  []
# 8 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00028r.xml :
# 			 DA a aplicar:  []
# 9 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00029f.xml :
# 			 DA a aplicar:  ['ng', 'ng']
# 				  da_c_SFeRS_00029f-ng.png  ya existe, se descata transformación!!
# 10 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00030fr.xml :
# 			 DA a aplicar:  []
# 11 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00031.xml :
# 			 DA a aplicar:  ['eh', 'ng']
# 			 % estiramiento  h :  65
# 12 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00032r.xml :
# 			 DA a aplicar:  ['nsp', 'eh', 'eh']
# 			 % estiramiento  h :  65
# 			 % estiramiento  h :  70
# 13 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00033fr.xml :
# 			 DA a aplicar:  []
# 14 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00034r.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  25
# 15 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00035r.xml :
# 			 DA a aplicar:  ['nsp']
# 16 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00036r.xml :
# 			 DA a aplicar:  ['ev', 'ng', 'nsp']
# 			 % estiramiento  v :  75
# 17 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00037.xml :
# 			 DA a aplicar:  ['ng', 'ng']
# 				  da_c_SFeRS_00037-ng.png  ya existe, se descata transformación!!
# 18 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00038fr.xml :
# 			 DA a aplicar:  ['z', 'eh']
# 			 % zoom:  50
# 			 % estiramiento  h :  60
# 19 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00039f.xml :
# 			 DA a aplicar:  ['nsp', 'z']
# 			 % zoom:  30
# 20 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00040f.xml :
# 			 DA a aplicar:  ['ev', 'z']
# 			 % estiramiento  v :  60
# 			 % zoom:  85
# 21 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00041r.xml :
# 			 DA a aplicar:  []
# 22 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00042r.xml :
# 			 DA a aplicar:  ['ng', 'nsp', 'eh']
# 			 % estiramiento  h :  65
# 23 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00043f.xml :
# 			 DA a aplicar:  []
# 24 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00044.xml :
# 			 DA a aplicar:  ['eh']
# 			 % estiramiento  h :  60
# 25 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00045r.xml :
# 			 DA a aplicar:  ['nsp']
# 26 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00046f.xml :
# 			 DA a aplicar:  ['ng', 'z', 'eh']
# 			 % zoom:  65
# 			 % estiramiento  h :  70
# 27 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00047fr.xml :
# 			 DA a aplicar:  []
# 28 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00048fr.xml :
# 			 DA a aplicar:  []
# 29 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00049f.xml :
# 			 DA a aplicar:  []
# 30 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00050.xml :
# 			 DA a aplicar:  ['z', 'eh']
# 			 % zoom:  60
# 			 % estiramiento  h :  60
# 31 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00051.xml :
# 			 DA a aplicar:  ['z', 'ev']
# 			 % zoom:  60
# 			 % estiramiento  v :  45
# 32 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00052fr.xml :
# 			 DA a aplicar:  []
# 33 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00053r.xml :
# 			 DA a aplicar:  []
# 34 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00054fr.xml :
# 			 DA a aplicar:  ['z', 'nsp']
# 			 % zoom:  35
# 35 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00055f.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  75
# 36 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00056r.xml :
# 			 DA a aplicar:  ['ev']
# 			 % estiramiento  v :  60
# 37 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00057r.xml :
# 			 DA a aplicar:  ['eh', 'ev', 'eh']
# 			 % estiramiento  h :  85
# 			 % estiramiento  v :  80
# 			 % estiramiento  h :  75
# 38 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00058r.xml :
# 			 DA a aplicar:  ['ev', 'ev']
# 			 % estiramiento  v :  65
# 			 % estiramiento  v :  65
# 				  da_c_SFeRS_00058r-ev65.png  ya existe, se descata transformación!!
# 39 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00059r.xml :
# 			 DA a aplicar:  []
# 40 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00060fr.xml :
# 			 DA a aplicar:  ['z', 'ng']
# 			 % zoom:  30
# 41 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00061f.xml :
# 			 DA a aplicar:  []
# 42 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00062fr.xml :
# 			 DA a aplicar:  ['eh', 'ev', 'z']
# 			 % estiramiento  h :  90
# 			 % estiramiento  v :  60
# 			 % zoom:  85
# 43 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00063r.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  75
# 44 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00064r.xml :
# 			 DA a aplicar:  ['eh', 'nsp']
# 			 % estiramiento  h :  60
# 45 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRS_00065.xml :
# 			 DA a aplicar:  ['eh', 'eh', 'ng']
# 			 % estiramiento  h :  55
# 			 % estiramiento  h :  45
# 46 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00001r.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  75
# 47 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00002fr.xml :
# 			 DA a aplicar:  ['ev']
# 			 % estiramiento  v :  70
# 48 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00003.xml :
# 			 DA a aplicar:  ['z', 'ng']
# 			 % zoom:  25
# 49 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00004fr.xml :
# 			 DA a aplicar:  ['ev', 'z', 'ev']
# 			 % estiramiento  v :  75
# 			 % zoom:  65
# 			 % estiramiento  v :  65
# 50 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00005fr.xml :
# 			 DA a aplicar:  ['eh', 'z', 'nsp']
# 			 % estiramiento  h :  45
# 			 % zoom:  40
# 51 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00006r.xml :
# 			 DA a aplicar:  ['nsp', 'ng', 'eh']
# 			 % estiramiento  h :  45
# 52 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00007fr.xml :
# 			 DA a aplicar:  []
# 53 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00008f.xml :
# 			 DA a aplicar:  ['eh', 'z']
# 			 % estiramiento  h :  55
# 			 % zoom:  20
# 54 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00009r.xml :
# 			 DA a aplicar:  ['z', 'ng']
# 			 % zoom:  75
# 55 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00010f.xml :
# 			 DA a aplicar:  ['ev', 'eh']
# 			 % estiramiento  v :  50
# 			 % estiramiento  h :  55
# 56 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00011r.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  80
# 57 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00012fr.xml :
# 			 DA a aplicar:  ['eh', 'z']
# 			 % estiramiento  h :  60
# 			 % zoom:  70
# 58 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00013fr.xml :
# 			 DA a aplicar:  []
# 59 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00014fr.xml :
# 			 DA a aplicar:  ['nsp']
# 60 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00015fr.xml :
# 			 DA a aplicar:  ['eh']
# 			 % estiramiento  h :  85
# 61 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00016r.xml :
# 			 DA a aplicar:  ['eh']
# 			 % estiramiento  h :  70
# 62 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00017r.xml :
# 			 DA a aplicar:  ['nsp', 'eh']
# 			 % estiramiento  h :  85
# 63 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00018r.xml :
# 			 DA a aplicar:  []
# 64 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00019fr.xml :
# 			 DA a aplicar:  ['nsp', 'eh']
# 			 % estiramiento  h :  60
# 65 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00020r.xml :
# 			 DA a aplicar:  ['nsp']
# 66 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00021fr.xml :
# 			 DA a aplicar:  ['ng', 'nsp', 'ng']
# 				  da_c_SFaRS_00021fr-ng.png  ya existe, se descata transformación!!
# 67 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00022r.xml :
# 			 DA a aplicar:  ['ev', 'z', 'eh']
# 			 % estiramiento  v :  80
# 			 % zoom:  65
# 			 % estiramiento  h :  75
# 68 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00023r.xml :
# 			 DA a aplicar:  []
# 69 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00024fr.xml :
# 			 DA a aplicar:  []
# 70 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00025fr.xml :
# 			 DA a aplicar:  ['ng']
# 71 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00026fr.xml :
# 			 DA a aplicar:  ['eh']
# 			 % estiramiento  h :  70
# 72 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00027f.xml :
# 			 DA a aplicar:  ['nsp']
# 73 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00028fr.xml :
# 			 DA a aplicar:  ['z', 'ng', 'z']
# 			 % zoom:  45
# 			 % zoom:  40
# 74 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00029r.xml :
# 			 DA a aplicar:  []
# 75 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00030r.xml :
# 			 DA a aplicar:  ['ev', 'eh', 'z']
# 			 % estiramiento  v :  75
# 			 % estiramiento  h :  80
# 			 % zoom:  25
# 76 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00031.xml :
# 			 DA a aplicar:  []
# 77 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00032.xml :
# 			 DA a aplicar:  []
# 78 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00033fr.xml :
# 			 DA a aplicar:  []
# 79 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00034fr.xml :
# 			 DA a aplicar:  ['z', 'z', 'eh']
# 			 % zoom:  55
# 			 % zoom:  70
# 			 % estiramiento  h :  45
# 80 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00035.xml :
# 			 DA a aplicar:  ['ev', 'ev', 'ng']
# 			 % estiramiento  v :  75
# 			 % estiramiento  v :  55
# 81 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00036r.xml :
# 			 DA a aplicar:  ['eh', 'z']
# 			 % estiramiento  h :  90
# 			 % zoom:  35
# 82 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00037r.xml :
# 			 DA a aplicar:  ['ng']
# 83 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00038fr.xml :
# 			 DA a aplicar:  ['eh', 'z', 'ng']
# 			 % estiramiento  h :  65
# 			 % zoom:  25
# 84 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00039r.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  40
# 85 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00040f.xml :
# 			 DA a aplicar:  ['ev', 'nsp', 'nsp']
# 			 % estiramiento  v :  70
# 				  da_c_SFaRS_00040f-nsp.png  ya existe, se descata transformación!!
# 86 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00041r.xml :
# 			 DA a aplicar:  ['eh', 'z']
# 			 % estiramiento  h :  70
# 			 % zoom:  25
# 87 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00042fr.xml :
# 			 DA a aplicar:  []
# 88 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00043fr.xml :
# 			 DA a aplicar:  []
# 89 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00044r.xml :
# 			 DA a aplicar:  []
# 90 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00045f.xml :
# 			 DA a aplicar:  []
# 91 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00046r.xml :
# 			 DA a aplicar:  ['nsp']
# 92 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00047r.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  40
# 93 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00048r.xml :
# 			 DA a aplicar:  ['z', 'z', 'ng']
# 			 % zoom:  35
# 			 % zoom:  25
# 94 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00049fr.xml :
# 			 DA a aplicar:  ['z', 'nsp']
# 			 % zoom:  40
# 95 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00050fr.xml :
# 			 DA a aplicar:  ['ng']
# 96 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00051r.xml :
# 			 DA a aplicar:  []
# 97 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00052r.xml :
# 			 DA a aplicar:  ['nsp']
# 98 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00053fr.xml :
# 			 DA a aplicar:  ['z', 'ng', 'ng']
# 			 % zoom:  35
# 				  da_c_SFaRS_00053fr-ng.png  ya existe, se descata transformación!!
# 99 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00054fr.xml :
# 			 DA a aplicar:  ['ng']
# 100 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00055f.xml :
# 			 DA a aplicar:  ['ev']
# 			 % estiramiento  v :  90
# 101 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00056.xml :
# 			 DA a aplicar:  ['eh', 'z', 'ng']
# 			 % estiramiento  h :  85
# 			 % zoom:  35
# 102 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00057.xml :
# 			 DA a aplicar:  ['z', 'z', 'ng']
# 			 % zoom:  60
# 			 % zoom:  80
# 103 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00058fr.xml :
# 			 DA a aplicar:  ['nsp']
# 104 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00059r.xml :
# 			 DA a aplicar:  ['z', 'z']
# 			 % zoom:  40
# 			 % zoom:  55
# 105 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00060r.xml :
# 			 DA a aplicar:  []
# 106 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00061r.xml :
# 			 DA a aplicar:  ['ev']
# 			 % estiramiento  v :  50
# 107 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00062r.xml :
# 			 DA a aplicar:  ['z', 'z']
# 			 % zoom:  45
# 			 % zoom:  40
# 108 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00063fr.xml :
# 			 DA a aplicar:  ['nsp', 'z', 'ev']
# 			 % zoom:  70
# 			 % estiramiento  v :  85
# 109 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00064r.xml :
# 			 DA a aplicar:  ['eh', 'ng', 'z']
# 			 % estiramiento  h :  55
# 			 % zoom:  30
# 110 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFaRS_00065fr.xml :
# 			 DA a aplicar:  ['ng', 'ng', 'nsp']
# 				  da_c_SFaRS_00065fr-ng.png  ya existe, se descata transformación!!
# 111 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00001r.xml :
# 			 DA a aplicar:  ['z', 'ng']
# 			 % zoom:  85
# 112 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00002f.xml :
# 			 DA a aplicar:  []
# 113 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00003fr.xml :
# 			 DA a aplicar:  ['z', 'ng']
# 			 % zoom:  80
# 114 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00004fr.xml :
# 			 DA a aplicar:  ['eh', 'ev']
# 			 % estiramiento  h :  90
# 			 % estiramiento  v :  55
# 115 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00005fr.xml :
# 			 DA a aplicar:  ['nsp']
# 116 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00006fr.xml :
# 			 DA a aplicar:  []
# 117 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00007fr.xml :
# 			 DA a aplicar:  ['ev']
# 			 % estiramiento  v :  50
# 118 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00008fr.xml :
# 			 DA a aplicar:  ['ev', 'z', 'ng']
# 			 % estiramiento  v :  75
# 			 % zoom:  55
# 119 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00009r.xml :
# 			 DA a aplicar:  []
# 120 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00010fr.xml :
# 			 DA a aplicar:  []
# 121 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00011r.xml :
# 			 DA a aplicar:  ['z', 'ev']
# 			 % zoom:  60
# 			 % estiramiento  v :  75
# 122 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00012.xml :
# 			 DA a aplicar:  ['nsp']
# 123 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00013r.xml :
# 			 DA a aplicar:  ['nsp']
# 124 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00014fr.xml :
# 			 DA a aplicar:  ['ng', 'z', 'nsp']
# 			 % zoom:  70
# 125 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00015fr.xml :
# 			 DA a aplicar:  ['nsp']
# 126 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00016r.xml :
# 			 DA a aplicar:  ['ev', 'ev', 'z']
# 			 % estiramiento  v :  50
# 			 % estiramiento  v :  85
# 			 % zoom:  25
# 127 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00017fr.xml :
# 			 DA a aplicar:  []
# 128 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00018fr.xml :
# 			 DA a aplicar:  []
# 129 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00019r.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  70
# 130 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00020fr.xml :
# 			 DA a aplicar:  ['eh', 'nsp', 'z']
# 			 % estiramiento  h :  70
# 			 % zoom:  40
# 131 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00021fr.xml :
# 			 DA a aplicar:  ['eh']
# 			 % estiramiento  h :  55
# 132 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00022r.xml :
# 			 DA a aplicar:  ['z', 'ng']
# 			 % zoom:  55
# 133 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00023r.xml :
# 			 DA a aplicar:  ['ev']
# 			 % estiramiento  v :  75
# 134 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00024fr.xml :
# 			 DA a aplicar:  []
# 135 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00025r.xml :
# 			 DA a aplicar:  []
# 136 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00026.xml :
# 			 DA a aplicar:  ['z', 'eh', 'ng']
# 			 % zoom:  40
# 			 % estiramiento  h :  65
# 137 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00027r.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  60
# 138 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00028r.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  45
# 139 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00029.xml :
# 			 DA a aplicar:  ['ev', 'z', 'nsp']
# 			 % estiramiento  v :  65
# 			 % zoom:  50
# 140 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00030fr.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  85
# 141 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00031f.xml :
# 			 DA a aplicar:  []
# 142 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00032fr.xml :
# 			 DA a aplicar:  []
# 143 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00033fr.xml :
# 			 DA a aplicar:  ['ng', 'nsp']
# 144 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00034r.xml :
# 			 DA a aplicar:  []
# 145 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00035fr.xml :
# 			 DA a aplicar:  ['z', 'z']
# 			 % zoom:  75
# 			 % zoom:  55
# 146 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00036r.xml :
# 			 DA a aplicar:  ['eh', 'z']
# 			 % estiramiento  h :  85
# 			 % zoom:  40
# 147 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00037r.xml :
# 			 DA a aplicar:  ['ev']
# 			 % estiramiento  v :  60
# 148 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00038r.xml :
# 			 DA a aplicar:  []
# 149 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00039r.xml :
# 			 DA a aplicar:  ['z', 'ng', 'nsp']
# 			 % zoom:  75
# 150 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00040fr.xml :
# 			 DA a aplicar:  []
# 151 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00041fr.xml :
# 			 DA a aplicar:  ['eh', 'eh', 'eh']
# 			 % estiramiento  h :  85
# 			 % estiramiento  h :  45
# 			 % estiramiento  h :  75
# 152 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00042fr.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  65
# 153 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00043fr.xml :
# 			 DA a aplicar:  ['eh']
# 			 % estiramiento  h :  45
# 154 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00044r.xml :
# 			 DA a aplicar:  ['nsp', 'eh', 'z']
# 			 % estiramiento  h :  50
# 			 % zoom:  20
# 155 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00045fr.xml :
# 			 DA a aplicar:  ['nsp', 'z']
# 			 % zoom:  70
# 156 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00046r.xml :
# 			 DA a aplicar:  ['z', 'ng']
# 			 % zoom:  70
# 157 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00047fr.xml :
# 			 DA a aplicar:  ['ev', 'nsp']
# 			 % estiramiento  v :  70
# 158 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00048r.xml :
# 			 DA a aplicar:  []
# 159 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00049r.xml :
# 			 DA a aplicar:  ['z', 'nsp']
# 			 % zoom:  60
# 160 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00050fr.xml :
# 			 DA a aplicar:  ['ng', 'ev']
# 			 % estiramiento  v :  70
# 161 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00051r.xml :
# 			 DA a aplicar:  []
# 162 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00052r.xml :
# 			 DA a aplicar:  ['ev', 'eh']
# 			 % estiramiento  v :  80
# 			 % estiramiento  h :  80
# 163 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00053r.xml :
# 			 DA a aplicar:  ['z', 'nsp', 'ng']
# 			 % zoom:  30
# 164 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00054r.xml :
# 			 DA a aplicar:  []
# 165 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00055fr.xml :
# 			 DA a aplicar:  ['nsp', 'z']
# 			 % zoom:  35
# 166 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00056r.xml :
# 			 DA a aplicar:  ['ng', 'eh', 'ev']
# 			 % estiramiento  h :  45
# 			 % estiramiento  v :  45
# 167 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00057fr.xml :
# 			 DA a aplicar:  ['ng']
# 168 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00058.xml :
# 			 DA a aplicar:  []
# 169 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00059.xml :
# 			 DA a aplicar:  []
# 170 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00060.xml :
# 			 DA a aplicar:  []
# 171 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00061r.xml :
# 			 DA a aplicar:  ['ng']
# 172 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00062fr.xml :
# 			 DA a aplicar:  []
# 173 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00063r.xml :
# 			 DA a aplicar:  []
# 174 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00064fr.xml :
# 			 DA a aplicar:  ['eh', 'z', 'eh']
# 			 % estiramiento  h :  75
# 			 % zoom:  60
# 			 % estiramiento  h :  90
# 175 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFoRS_00065fr.xml :
# 			 DA a aplicar:  ['ng', 'z']
# 			 % zoom:  75
# 176 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00001fr.xml :
# 			 DA a aplicar:  []
# 177 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00002r.xml :
# 			 DA a aplicar:  ['nsp', 'ng']
# 178 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00003fr.xml :
# 			 DA a aplicar:  []
# 179 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00004s.xml :
# 			 DA a aplicar:  ['eh', 'z']
# 			 % estiramiento  h :  50
# 			 % zoom:  50
# 180 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00005r.xml :
# 			 DA a aplicar:  []
# 181 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00006fs.xml :
# 			 DA a aplicar:  ['nsp', 'eh', 'z']
# 			 % estiramiento  h :  60
# 			 % zoom:  85
# 182 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00007r.xml :
# 			 DA a aplicar:  ['eh', 'ng']
# 			 % estiramiento  h :  75
# 183 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00008r.xml :
# 			 DA a aplicar:  ['nsp']
# 184 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00009fr.xml :
# 			 DA a aplicar:  ['ng']
# 185 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00010fr.xml :
# 			 DA a aplicar:  []
# 186 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00011fs.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  50
# 187 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00012r.xml :
# 			 DA a aplicar:  []
# 188 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00013fr.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  75
# 189 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00014fr.xml :
# 			 DA a aplicar:  ['eh', 'nsp']
# 			 % estiramiento  h :  65
# 190 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00015s.xml :
# 			 DA a aplicar:  ['ng', 'z']
# 			 % zoom:  45
# 191 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00016fs.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  20
# 192 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00017r.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  45
# 193 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00018fs.xml :
# 			 DA a aplicar:  ['z', 'eh']
# 			 % zoom:  25
# 			 % estiramiento  h :  50
# 194 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00019fs.xml :
# 			 DA a aplicar:  ['z', 'eh', 'nsp']
# 			 % zoom:  35
# 			 % estiramiento  h :  50
# 195 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00020fr.xml :
# 			 DA a aplicar:  ['nsp', 'eh']
# 			 % estiramiento  h :  90
# 196 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00021s.xml :
# 			 DA a aplicar:  ['z', 'z']
# 			 % zoom:  80
# 			 % zoom:  20
# 197 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00022s.xml :
# 			 DA a aplicar:  []
# 198 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00023fr.xml :
# 			 DA a aplicar:  ['nsp', 'z']
# 			 % zoom:  75
# 199 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00024r.xml :
# 			 DA a aplicar:  ['ng']
# 200 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00025fs.xml :
# 			 DA a aplicar:  ['nsp', 'ev', 'ev']
# 			 % estiramiento  v :  75
# 			 % estiramiento  v :  50
# 201 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00026fr.xml :
# 			 DA a aplicar:  ['nsp']
# 202 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00027r.xml :
# 			 DA a aplicar:  ['eh', 'nsp', 'z']
# 			 % estiramiento  h :  75
# 			 % zoom:  60
# 203 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00028fr.xml :
# 			 DA a aplicar:  []
# 204 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00029fs.xml :
# 			 DA a aplicar:  ['nsp', 'nsp']
# 				  da_c_SFdRA_00029fs-nsp.png  ya existe, se descata transformación!!
# 205 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00030fs.xml :
# 			 DA a aplicar:  []
# 206 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00031r.xml :
# 			 DA a aplicar:  []
# 207 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00032fr.xml :
# 			 DA a aplicar:  ['ev', 'ng']
# 			 % estiramiento  v :  90
# 208 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00033fs.xml :
# 			 DA a aplicar:  []
# 209 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00034fr.xml :
# 			 DA a aplicar:  ['z', 'ev', 'ng']
# 			 % zoom:  60
# 			 % estiramiento  v :  60
# 210 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00035fs.xml :
# 			 DA a aplicar:  ['ev']
# 			 % estiramiento  v :  75
# 211 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00036s.xml :
# 			 DA a aplicar:  []
# 212 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00037fs.xml :
# 			 DA a aplicar:  []
# 213 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00038s.xml :
# 			 DA a aplicar:  ['ng', 'eh', 'eh']
# 			 % estiramiento  h :  85
# 			 % estiramiento  h :  90
# 214 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00039s.xml :
# 			 DA a aplicar:  ['eh', 'z']
# 			 % estiramiento  h :  75
# 			 % zoom:  50
# 215 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00040fs.xml :
# 			 DA a aplicar:  ['ng']
# 216 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00041fr.xml :
# 			 DA a aplicar:  []
# 217 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00042r.xml :
# 			 DA a aplicar:  ['z', 'ev', 'nsp']
# 			 % zoom:  35
# 			 % estiramiento  v :  60
# 218 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00043r.xml :
# 			 DA a aplicar:  ['nsp']
# 219 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00044s.xml :
# 			 DA a aplicar:  []
# 220 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00045fr.xml :
# 			 DA a aplicar:  []
# 221 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00046fs.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  65
# 222 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00047r.xml :
# 			 DA a aplicar:  ['ev', 'nsp', 'eh']
# 			 % estiramiento  v :  50
# 			 % estiramiento  h :  45
# 223 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00048fr.xml :
# 			 DA a aplicar:  []
# 224 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00049r.xml :
# 			 DA a aplicar:  []
# 225 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00050s.xml :
# 			 DA a aplicar:  ['eh']
# 			 % estiramiento  h :  80
# 226 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00051s.xml :
# 			 DA a aplicar:  ['eh']
# 			 % estiramiento  h :  75
# 227 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00052s.xml :
# 			 DA a aplicar:  ['ev', 'z']
# 			 % estiramiento  v :  80
# 			 % zoom:  55
# 228 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00053s.xml :
# 			 DA a aplicar:  ['ev', 'ng']
# 			 % estiramiento  v :  45
# 229 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00054s.xml :
# 			 DA a aplicar:  []
# 230 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00055fr.xml :
# 			 DA a aplicar:  ['z', 'eh']
# 			 % zoom:  55
# 			 % estiramiento  h :  65
# 231 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00056fr.xml :
# 			 DA a aplicar:  ['ng']
# 232 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00057fr.xml :
# 			 DA a aplicar:  []
# 233 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00058r.xml :
# 			 DA a aplicar:  ['eh']
# 			 % estiramiento  h :  60
# 234 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00059fr.xml :
# 			 DA a aplicar:  ['ng', 'ev', 'eh']
# 			 % estiramiento  v :  55
# 			 % estiramiento  h :  65
# 235 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00060s.xml :
# 			 DA a aplicar:  []
# 236 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00061fr.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  70
# 237 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00062fs.xml :
# 			 DA a aplicar:  ['z', 'ng']
# 			 % zoom:  80
# 238 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00063fr.xml :
# 			 DA a aplicar:  []
# 239 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00064fr.xml :
# 			 DA a aplicar:  ['eh', 'z', 'eh']
# 			 % estiramiento  h :  65
# 			 % zoom:  55
# 			 % estiramiento  h :  85
# 240 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFdRA_00065fr.xml :
# 			 DA a aplicar:  []
# 241 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00001fr.xml :
# 			 DA a aplicar:  []
# 242 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00002r.xml :
# 			 DA a aplicar:  ['ev', 'eh']
# 			 % estiramiento  v :  50
# 			 % estiramiento  h :  75
# 243 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00003fr.xml :
# 			 DA a aplicar:  []
# 244 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00004fs.xml :
# 			 DA a aplicar:  []
# 245 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00005fr.xml :
# 			 DA a aplicar:  ['nsp', 'z', 'z']
# 			 % zoom:  40
# 			 % zoom:  75
# 246 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00006s.xml :
# 			 DA a aplicar:  ['z', 'z', 'nsp']
# 			 % zoom:  85
# 			 % zoom:  85
# 				  da_c_SFcRA_00006s-z85.png  ya existe, se descata transformación!!
# 247 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00007r.xml :
# 			 DA a aplicar:  ['eh']
# 			 % estiramiento  h :  90
# 248 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00008s.xml :
# 			 DA a aplicar:  []
# 249 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00009r.xml :
# 			 DA a aplicar:  ['ev', 'eh', 'ng']
# 			 % estiramiento  v :  80
# 			 % estiramiento  h :  85
# 250 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00010fr.xml :
# 			 DA a aplicar:  ['nsp', 'ng']
# 251 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00011fr.xml :
# 			 DA a aplicar:  ['nsp']
# 252 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00012s.xml :
# 			 DA a aplicar:  []
# 253 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00013r.xml :
# 			 DA a aplicar:  ['eh', 'nsp']
# 			 % estiramiento  h :  90
# 254 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00014fs.xml :
# 			 DA a aplicar:  ['nsp', 'ng']
# 255 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00015fr.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  65
# 256 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00016fs.xml :
# 			 DA a aplicar:  ['nsp', 'eh']
# 			 % estiramiento  h :  65
# 257 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00017fr.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  65
# 258 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00018s.xml :
# 			 DA a aplicar:  []
# 259 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00019fs.xml :
# 			 DA a aplicar:  []
# 260 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00020s.xml :
# 			 DA a aplicar:  ['z', 'nsp']
# 			 % zoom:  40
# 261 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00021r.xml :
# 			 DA a aplicar:  ['ev', 'eh']
# 			 % estiramiento  v :  90
# 			 % estiramiento  h :  60
# 262 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00022fs.xml :
# 			 DA a aplicar:  []
# 263 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00023fr.xml :
# 			 DA a aplicar:  ['nsp', 'nsp']
# 				  da_c_SFcRA_00023fr-nsp.png  ya existe, se descata transformación!!
# 264 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00024fs.xml :
# 			 DA a aplicar:  ['z', 'z']
# 			 % zoom:  50
# 			 % zoom:  35
# 265 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00025fs.xml :
# 			 DA a aplicar:  ['nsp', 'ng', 'nsp']
# 				  da_c_SFcRA_00025fs-nsp.png  ya existe, se descata transformación!!
# 266 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00026r.xml :
# 			 DA a aplicar:  ['eh', 'ev', 'nsp']
# 			 % estiramiento  h :  65
# 			 % estiramiento  v :  90
# 267 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00027fs.xml :
# 			 DA a aplicar:  []
# 268 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00028fs.xml :
# 			 DA a aplicar:  ['ng', 'z']
# 			 % zoom:  55
# 269 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00029fs.xml :
# 			 DA a aplicar:  ['ev', 'nsp', 'z']
# 			 % estiramiento  v :  65
# 			 % zoom:  55
# 270 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00030r.xml :
# 			 DA a aplicar:  []
# 271 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00031s.xml :
# 			 DA a aplicar:  ['z', 'z', 'eh']
# 			 % zoom:  30
# 			 % zoom:  40
# 			 % estiramiento  h :  80
# 272 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00032r.xml :
# 			 DA a aplicar:  ['eh', 'ng', 'z']
# 			 % estiramiento  h :  75
# 			 % zoom:  40
# 273 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00033r.xml :
# 			 DA a aplicar:  ['ev']
# 			 % estiramiento  v :  45
# 274 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00034r.xml :
# 			 DA a aplicar:  []
# 275 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00035fr.xml :
# 			 DA a aplicar:  ['eh']
# 			 % estiramiento  h :  75
# 276 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00036fr.xml :
# 			 DA a aplicar:  ['ng', 'ng', 'z']
# 				  da_c_SFcRA_00036fr-ng.png  ya existe, se descata transformación!!
# 			 % zoom:  65
# 277 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00037r.xml :
# 			 DA a aplicar:  ['z', 'nsp', 'z']
# 			 % zoom:  25
# 			 % zoom:  50
# 278 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00038r.xml :
# 			 DA a aplicar:  ['nsp']
# 279 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00039fs.xml :
# 			 DA a aplicar:  []
# 280 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00040fr.xml :
# 			 DA a aplicar:  ['nsp']
# 281 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00041r.xml :
# 			 DA a aplicar:  []
# 282 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00042fs.xml :
# 			 DA a aplicar:  []
# 283 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00043fr.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  85
# 284 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00044fr.xml :
# 			 DA a aplicar:  []
# 285 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00045s.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  55
# 286 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00046r.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  80
# 287 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00047fr.xml :
# 			 DA a aplicar:  ['ev']
# 			 % estiramiento  v :  60
# 288 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00048fr.xml :
# 			 DA a aplicar:  ['z', 'ev']
# 			 % zoom:  35
# 			 % estiramiento  v :  75
# 289 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00049s.xml :
# 			 DA a aplicar:  ['z', 'ng']
# 			 % zoom:  85
# 290 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00050fr.xml :
# 			 DA a aplicar:  ['eh']
# 			 % estiramiento  h :  60
# 291 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00051fs.xml :
# 			 DA a aplicar:  ['z', 'z', 'z']
# 			 % zoom:  30
# 			 % zoom:  35
# 			 % zoom:  55
# 292 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00052fs.xml :
# 			 DA a aplicar:  ['z', 'z', 'ev']
# 			 % zoom:  65
# 			 % zoom:  20
# 			 % estiramiento  v :  45
# 293 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00053s.xml :
# 			 DA a aplicar:  ['eh']
# 			 % estiramiento  h :  90
# 294 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00054fs.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  45
# 295 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00055fr.xml :
# 			 DA a aplicar:  ['nsp', 'ng']
# 296 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00056r.xml :
# 			 DA a aplicar:  []
# 297 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00057fr.xml :
# 			 DA a aplicar:  ['ev', 'eh']
# 			 % estiramiento  v :  80
# 			 % estiramiento  h :  70
# 298 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00058r.xml :
# 			 DA a aplicar:  ['nsp', 'z']
# 			 % zoom:  25
# 299 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00059r.xml :
# 			 DA a aplicar:  ['ev']
# 			 % estiramiento  v :  80
# 300 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00060s.xml :
# 			 DA a aplicar:  ['eh', 'z']
# 			 % estiramiento  h :  85
# 			 % zoom:  85
# 301 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00061fs.xml :
# 			 DA a aplicar:  []
# 302 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00062fr.xml :
# 			 DA a aplicar:  []
# 303 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00063fr.xml :
# 			 DA a aplicar:  ['eh', 'eh']
# 			 % estiramiento  h :  45
# 			 % estiramiento  h :  70
# 304 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00064r.xml :
# 			 DA a aplicar:  ['eh', 'ev']
# 			 % estiramiento  h :  65
# 			 % estiramiento  v :  75
# 305 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFcRA_00065r.xml :
# 			 DA a aplicar:  ['eh', 'z']
# 			 % estiramiento  h :  50
# 			 % zoom:  85
# 306 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRA_00001fr.xml :
# 			 DA a aplicar:  ['z', 'z']
# 			 % zoom:  85
# 			 % zoom:  75
# 307 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRA_00002f.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  25
# 308 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRA_00003f.xml :
# 			 DA a aplicar:  ['ng']
# 309 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SFeRA_00004.xml :
# ...
# 1401 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00011s.xml :
# 			 DA a aplicar:  []
# 1402 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00012fr.xml :
# 			 DA a aplicar:  []
# 1403 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00013f.xml :
# 			 DA a aplicar:  ['ev', 'nsp']
# 			 % estiramiento  v :  60
# 1404 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00014r.xml :
# 			 DA a aplicar:  ['nsp', 'z', 'ng']
# 			 % zoom:  85
# 1405 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00015fs.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  65
# 1406 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00016f.xml :
# 			 DA a aplicar:  []
# 1407 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00017r.xml :
# 			 DA a aplicar:  ['eh', 'z']
# 			 % estiramiento  h :  75
# 			 % zoom:  50
# 1408 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00018fr.xml :
# 			 DA a aplicar:  []
# 1409 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00019.xml :
# 			 DA a aplicar:  ['z', 'eh', 'nsp']
# 			 % zoom:  20
# 			 % estiramiento  h :  80
# 1410 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00020fr.xml :
# 			 DA a aplicar:  ['ng', 'z', 'eh']
# 			 % zoom:  40
# 			 % estiramiento  h :  70
# 1411 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00021f.xml :
# 			 DA a aplicar:  []
# 1412 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00022fr.xml :
# 			 DA a aplicar:  ['eh', 'nsp', 'z']
# 			 % estiramiento  h :  75
# 			 % zoom:  35
# 1413 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00023fs.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  45
# 1414 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00024f.xml :
# 			 DA a aplicar:  ['ev']
# 			 % estiramiento  v :  70
# 1415 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00025f.xml :
# 			 DA a aplicar:  ['eh', 'ev']
# 			 % estiramiento  h :  70
# 			 % estiramiento  v :  55
# 1416 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00026s.xml :
# 			 DA a aplicar:  ['nsp', 'ng', 'nsp']
# 				  da_c_SPRC_00026s-nsp.png  ya existe, se descata transformación!!
# 1417 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00027fr.xml :
# 			 DA a aplicar:  []
# 1418 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00028.xml :
# 			 DA a aplicar:  ['ng', 'ev', 'ng']
# 			 % estiramiento  v :  45
# 				  da_c_SPRC_00028-ng.png  ya existe, se descata transformación!!
# 1419 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00029s.xml :
# 			 DA a aplicar:  ['ev']
# 			 % estiramiento  v :  70
# 1420 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00030.xml :
# 			 DA a aplicar:  ['z', 'z']
# 			 % zoom:  80
# 			 % zoom:  80
# 				  da_c_SPRC_00030-z80.png  ya existe, se descata transformación!!
# 1421 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00031r.xml :
# 			 DA a aplicar:  ['ev', 'eh', 'z']
# 			 % estiramiento  v :  50
# 			 % estiramiento  h :  45
# 			 % zoom:  75
# 1422 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00032f.xml :
# 			 DA a aplicar:  ['ev', 'nsp', 'ng']
# 			 % estiramiento  v :  55
# 1423 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00033fr.xml :
# 			 DA a aplicar:  ['ev']
# 			 % estiramiento  v :  50
# 1424 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00034f.xml :
# 			 DA a aplicar:  ['eh']
# 			 % estiramiento  h :  50
# 1425 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00035fr.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  85
# 1426 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00036fs.xml :
# 			 DA a aplicar:  []
# 1427 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00037s.xml :
# 			 DA a aplicar:  ['nsp', 'eh', 'nsp']
# 			 % estiramiento  h :  75
# 				  da_c_SPRC_00037s-nsp.png  ya existe, se descata transformación!!
# 1428 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00038fs.xml :
# 			 DA a aplicar:  ['eh']
# 			 % estiramiento  h :  80
# 1429 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00039s.xml :
# 			 DA a aplicar:  ['eh', 'eh', 'z']
# 			 % estiramiento  h :  65
# 			 % estiramiento  h :  65
# 				  da_c_SPRC_00039s-eh65.png  ya existe, se descata transformación!!
# 			 % zoom:  20
# 1430 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00040f.xml :
# 			 DA a aplicar:  ['z', 'z']
# 			 % zoom:  45
# 			 % zoom:  85
# 1431 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00041.xml :
# 			 DA a aplicar:  ['z', 'ng', 'z']
# 			 % zoom:  80
# 			 % zoom:  25
# 1432 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00042r.xml :
# 			 DA a aplicar:  []
# 1433 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00043.xml :
# 			 DA a aplicar:  ['z', 'nsp', 'nsp']
# 			 % zoom:  65
# 				  da_c_SPRC_00043-nsp.png  ya existe, se descata transformación!!
# 1434 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00044f.xml :
# 			 DA a aplicar:  []
# 1435 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00045r.xml :
# 			 DA a aplicar:  ['eh', 'z']
# 			 % estiramiento  h :  45
# 			 % zoom:  80
# 1436 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00046.xml :
# 			 DA a aplicar:  ['ng', 'ng', 'z']
# 				  da_c_SPRC_00046-ng.png  ya existe, se descata transformación!!
# 			 % zoom:  35
# 1437 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00047fr.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  75
# 1438 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00048r.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  30
# 1439 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00049fs.xml :
# 			 DA a aplicar:  ['eh', 'nsp', 'nsp']
# 			 % estiramiento  h :  60
# 				  da_c_SPRC_00049fs-nsp.png  ya existe, se descata transformación!!
# 1440 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00050.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  35
# 1441 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00051f.xml :
# 			 DA a aplicar:  ['z', 'ev']
# 			 % zoom:  65
# 			 % estiramiento  v :  80
# 1442 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00052fr.xml :
# 			 DA a aplicar:  ['ng', 'nsp']
# 1443 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00053fs.xml :
# 			 DA a aplicar:  ['eh', 'ev', 'nsp']
# 			 % estiramiento  h :  65
# 			 % estiramiento  v :  75
# 1444 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00054fr.xml :
# 			 DA a aplicar:  ['ng', 'ev', 'eh']
# 			 % estiramiento  v :  70
# 			 % estiramiento  h :  55
# 1445 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00055.xml :
# 			 DA a aplicar:  []
# 1446 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00056fr.xml :
# 			 DA a aplicar:  []
# 1447 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00057fr.xml :
# 			 DA a aplicar:  []
# 1448 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00058f.xml :
# 			 DA a aplicar:  ['z', 'ng']
# 			 % zoom:  65
# 1449 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00059s.xml :
# 			 DA a aplicar:  ['ev']
# 			 % estiramiento  v :  50
# 1450 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00060fr.xml :
# 			 DA a aplicar:  ['ng']
# 1451 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00061f.xml :
# 			 DA a aplicar:  []
# 1452 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00062fr.xml :
# 			 DA a aplicar:  ['nsp', 'nsp', 'ev']
# 				  da_c_SPRC_00062fr-nsp.png  ya existe, se descata transformación!!
# 			 % estiramiento  v :  45
# 1453 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00063fr.xml :
# 			 DA a aplicar:  ['eh', 'ng', 'z']
# 			 % estiramiento  h :  45
# 			 % zoom:  75
# 1454 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00064fr.xml :
# 			 DA a aplicar:  ['nsp', 'ev', 'ev']
# 			 % estiramiento  v :  65
# 			 % estiramiento  v :  65
# 				  da_c_SPRC_00064fr-ev65.png  ya existe, se descata transformación!!
# 1455 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRC_00065f.xml :
# 			 DA a aplicar:  []
# 1456 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00001f.xml :
# 			 DA a aplicar:  ['eh', 'ev', 'ng']
# 			 % estiramiento  h :  55
# 			 % estiramiento  v :  90
# 1457 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00002.xml :
# 			 DA a aplicar:  ['z', 'ng']
# 			 % zoom:  25
# 1458 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00003s.xml :
# 			 DA a aplicar:  ['z', 'ev']
# 			 % zoom:  55
# 			 % estiramiento  v :  65
# 1459 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00004fr.xml :
# 			 DA a aplicar:  ['nsp', 'z', 'nsp']
# 			 % zoom:  35
# 				  da_c_SPRS_00004fr-nsp.png  ya existe, se descata transformación!!
# 1460 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00005fr.xml :
# 			 DA a aplicar:  []
# 1461 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00006.xml :
# 			 DA a aplicar:  ['z', 'eh', 'eh']
# 			 % zoom:  20
# 			 % estiramiento  h :  70
# 			 % estiramiento  h :  75
# 1462 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00007fr.xml :
# 			 DA a aplicar:  []
# 1463 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00008fr.xml :
# 			 DA a aplicar:  ['ng']
# 1464 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00009.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  35
# 1465 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00010r.xml :
# 			 DA a aplicar:  ['eh']
# 			 % estiramiento  h :  55
# 1466 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00011.xml :
# 			 DA a aplicar:  ['ev', 'nsp', 'z']
# 			 % estiramiento  v :  55
# 			 % zoom:  45
# 1467 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00012f.xml :
# 			 DA a aplicar:  ['nsp']
# 1468 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00013.xml :
# 			 DA a aplicar:  ['z', 'nsp', 'eh']
# 			 % zoom:  30
# 			 % estiramiento  h :  55
# 1469 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00014r.xml :
# 			 DA a aplicar:  ['nsp', 'nsp', 'ev']
# 				  da_c_SPRS_00014r-nsp.png  ya existe, se descata transformación!!
# 			 % estiramiento  v :  65
# 1470 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00015.xml :
# 			 DA a aplicar:  ['eh', 'z']
# 			 % estiramiento  h :  45
# 			 % zoom:  75
# 1471 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00016fr.xml :
# 			 DA a aplicar:  []
# 1472 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00017s.xml :
# 			 DA a aplicar:  []
# 1473 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00018r.xml :
# 			 DA a aplicar:  ['ng']
# 1474 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00019f.xml :
# 			 DA a aplicar:  ['nsp', 'ng']
# 1475 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00020f.xml :
# 			 DA a aplicar:  ['eh', 'ev', 'z']
# 			 % estiramiento  h :  55
# 			 % estiramiento  v :  65
# 			 % zoom:  70
# 1476 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00021f.xml :
# 			 DA a aplicar:  ['ng', 'z']
# 			 % zoom:  30
# 1477 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00022.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  75
# 1478 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00023f.xml :
# 			 DA a aplicar:  ['ev', 'z']
# 			 % estiramiento  v :  80
# 			 % zoom:  35
# 1479 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00024fr.xml :
# 			 DA a aplicar:  []
# 1480 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00025fr.xml :
# 			 DA a aplicar:  ['ng', 'eh']
# 			 % estiramiento  h :  85
# 1481 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00026.xml :
# 			 DA a aplicar:  []
# 1482 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00027f.xml :
# 			 DA a aplicar:  ['z', 'nsp', 'z']
# 			 % zoom:  85
# 			 % zoom:  75
# 1483 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00028fr.xml :
# 			 DA a aplicar:  ['ev', 'ev']
# 			 % estiramiento  v :  80
# 			 % estiramiento  v :  65
# 1484 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00029fr.xml :
# 			 DA a aplicar:  ['eh', 'z', 'nsp']
# 			 % estiramiento  h :  60
# 			 % zoom:  75
# 1485 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00030s.xml :
# 			 DA a aplicar:  ['z', 'nsp', 'ng']
# 			 % zoom:  70
# 1486 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00031r.xml :
# 			 DA a aplicar:  ['z', 'nsp', 'z']
# 			 % zoom:  35
# 			 % zoom:  65
# 1487 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00032.xml :
# 			 DA a aplicar:  ['z', 'ng', 'eh']
# 			 % zoom:  40
# 			 % estiramiento  h :  85
# 1488 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00033fr.xml :
# 			 DA a aplicar:  ['nsp']
# 1489 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00034r.xml :
# 			 DA a aplicar:  []
# 1490 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00035fr.xml :
# 			 DA a aplicar:  ['ev']
# 			 % estiramiento  v :  50
# 1491 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00036r.xml :
# 			 DA a aplicar:  []
# 1492 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00037.xml :
# 			 DA a aplicar:  []
# 1493 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00038f.xml :
# 			 DA a aplicar:  ['ng']
# 1494 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00039s.xml :
# 			 DA a aplicar:  ['ng']
# 1495 -  /content/gdrive/MyDrive/GEMIS/objDetectionCursogramas/Cursogramas/Generados/c_SPRS_00040f.xml :
# 			 DA a aplicar:  ['z']
# 			 % zoom:  35
#
# *** Fin procesamiento de de XMLs para generar nuevas imágenes ***
#
#
# > Imágenes/XMLs procesados:  1495
# > Imágenes nuevas generadas:  2081
# > XMLs nuevas generados:  2081
#
# ** Forzando la actualización del drive **
# Mounted at /content/gdrive
# **Actualización del drive terminada **

# %%
#@title Borrar archivos XMLs con su imagen (por si tienen algún problema)
Confirmar_borrado_archivos_DA = False #@param {type:"boolean"}

if Confirmar_borrado_archivos_DA:

  XMLAr = [os.path.join(xml_path, fn) for fn in os.listdir(xml_path) if fn.endswith('.xml') and fn.startswith(prefijo_archivo_da) ]
  print("\n** Borrando ", len(XMLAr), "archivos XML del drive **")
  for a in XMLAr:
    os.remove( a )

  PNGAr = [os.path.join(img_path, fn) for fn in os.listdir(img_path) if fn.endswith('.png') and fn.startswith(prefijo_archivo_da) ]
  print("\n** Borrando ", len(PNGAr), "archivos PNG del drive **")
  for a in PNGAr:
    os.remove( a)

  print("\n** Borrando archivos terminado **")

  if forzar_drive_actualizar:
    print("\n** Forzando la actualización del drive **")
    # Fuerza la actualizacion del drive
    drive.flush_and_unmount()
    # vuelve a montar
    drive.mount('/content/gdrive', force_remount=True)
    print("**Actualización del drive terminada **")

# resetea la variable para no borrar por error
Confirmar_borrado_archivos_DA = False
